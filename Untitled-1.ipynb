# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
a= print(df.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None

# %%
print(df.describe())
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
print(df.shape)
# Out:
# (8807, 12)

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %%
df.dropna(subset=['director'], inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %%
df['country'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\harshit sinotiya\AppData\Local\Temp\ipykernel_5084\2372192134.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna('Unknown', inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %%
df['cast'].fillna('No Cast Info', inplace=True)
# Out:
# C:\Users\harshit sinotiya\AppData\Local\Temp\ipykernel_5084\118326653.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].fillna('No Cast Info', inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %%
print(f"Duplicates: {df.duplicated().sum()}")
# Out:
# Duplicates: 0

# %%
df.drop_duplicates(inplace=True)

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %%
df['num_cast'] = df['cast'].apply(lambda x: len(str(x).split(',')) if pd.notnull(x) else 0)

# %%
df['num_cast']
# Out:
# 0        1
# 2        9
# 5       16
# 6       10
# 7        8
#         ..
# 8801     6
# 8802    10
# 8804     7
# 8805     9
# 8806     8
# Name: num_cast, Length: 6173, dtype: int64

# %%
netflix_movies = df[df['type'] == 'Movie']

# %%
df.sort_values('release_year', ascending=False)
# Out:
#      show_id   type                                          title  \
# 64       s65  Movie                                     Nightbooks
# 1220   s1221  Movie                               Coven of Sisters
# 68       s69  Movie                                     Schumacher
# 71       s72  Movie                    A StoryBots Space Adventure
# 18       s19  Movie                                      Intrusion
# ...      ...    ...                                            ...
# 8739   s8740  Movie             Why We Fight: The Battle of Russia
# 8763   s8764  Movie                WWII: Report from the Aleutians
# 8660   s8661  Movie  Undercover: How to Operate Behind Enemy Lines
# 8205   s8206  Movie                           The Battle of Midway
# 7790   s7791  Movie                                 Prelude to War
#
#                                                director  \
# 64                                      David Yarovesky
# 1220                                       Pablo Agüero
# 68    Hanns-Bruno Kammertöns, Vanessa Nöcker, Michae...
# 71                                      David A. Vargas
# 18                                           Adam Salky
# ...                                                 ...
# 8739                        Frank Capra, Anatole Litvak
# 8763                                        John Huston
# 8660                                          John Ford
# 8205                                          John Ford
# 7790                                        Frank Capra
#
#                                                    cast           country  \
# 64         Winslow Fegley, Lidya Jewett, Krysten Ritter           Unknown
# 1220  Alex Brendemühl, Amaia Aberasturi, Daniel Fane...  Spain, Argentina
# 68                                   Michael Schumacher           Unknown
# 71    Evan Spiridellis, Erin Fitzgerald, Jeff Gill, ...           Unknown
# 18    Freida Pinto, Logan Marshall-Green, Robert Joh...           Unknown
# ...                                                 ...               ...
# 8739                                       No Cast Info     United States
# 8763                                       No Cast Info     United States
# 8660                                       No Cast Info     United States
# 8205                          Henry Fonda, Jane Darwell     United States
# 7790                                       No Cast Info     United States
#
#      date_added  release_year rating duration  \
# 64   2021-09-15          2021  TV-PG  103 min
# 1220 2021-03-11          2021  TV-MA   92 min
# 68   2021-09-15          2021  TV-14  113 min
# 71   2021-09-14          2021   TV-Y   13 min
# 18   2021-09-22          2021  TV-14   94 min
# ...         ...           ...    ...      ...
# 8739 2017-03-31          1943  TV-PG   82 min
# 8763 2017-03-31          1943  TV-PG   45 min
# 8660 2017-03-31          1943  TV-PG   61 min
# 8205 2017-03-31          1942  TV-14   18 min
# 7790 2017-03-31          1942  TV-14   52 min
#
#                                               listed_in  \
# 64                             Children & Family Movies
# 1220   Dramas, Independent Movies, International Movies
# 68    Documentaries, International Movies, Sports Mo...
# 71                             Children & Family Movies
# 18                                            Thrillers
# ...                                                 ...
# 8739                                      Documentaries
# 8763                                      Documentaries
# 8660                      Classic Movies, Documentaries
# 8205                      Classic Movies, Documentaries
# 7790                      Classic Movies, Documentaries
#
#                                             description  num_cast
# 64    Scary story fan Alex must tell a spine-tinglin...         3
# 1220  Basque Country, 1609. To postpone their execut...         8
# 68    Through exclusive interviews and archival foot...         1
# 71    Join the StoryBots and the space travelers of ...         9
# 18    After a deadly home invasion at a couple’s new...        10
# ...                                                 ...       ...
# 8739  This installment of Frank Capra's acclaimed do...         1
# 8763  Filmmaker John Huston narrates this Oscar-nomi...         1
# 8660  This World War II-era training film dramatizes...         1
# 8205  Director John Ford captures combat footage of ...         2
# 7790  Frank Capra's documentary chronicles the rise ...         1
#
# [6173 rows x 13 columns]

# %%
content_per_country = df.groupby('country').size().sort_values(ascending=False).head(10)
print(content_per_country)
# Out:
# country
# United States     2048
# India              890
# Unknown            422
# United Kingdom     212
# Canada             119
# Spain              106
# Nigeria             90
# Egypt               90
# Japan               85
# France              81
# dtype: int64

# %%
print(df.describe(include='all'))
# Out:
#        show_id   type   title       director          cast        country  \
# count     6173   6173    6173           6173          6173           6173
# unique    6173      2    6173           4528          5513            659
# top      s8807  Movie  Zubaan  Rajiv Chilaka  No Cast Info  United States
# freq         1   5943       1             19           473           2048
# mean       NaN    NaN     NaN            NaN           NaN            NaN
# min        NaN    NaN     NaN            NaN           NaN            NaN
# 25%        NaN    NaN     NaN            NaN           NaN            NaN
# 50%        NaN    NaN     NaN            NaN           NaN            NaN
# 75%        NaN    NaN     NaN            NaN           NaN            NaN
# max        NaN    NaN     NaN            NaN           NaN            NaN
# std        NaN    NaN     NaN            NaN           NaN            NaN
#
#                            date_added  release_year rating  duration  \
# count                            6168   6173.000000   6172      6170
# unique                            NaN           NaN     17       211
# top                               NaN           NaN  TV-MA  1 Season
# freq                              NaN           NaN   2117       184
# mean    2019-05-15 04:18:12.607003904   2013.180625    NaN       NaN
# min               2008-01-01 00:00:00   1942.000000    NaN       NaN
# 25%               2018-04-04 00:00:00   2012.000000    NaN       NaN
# 50%               2019-07-01 00:00:00   2016.000000    NaN       NaN
# 75%               2020-08-02 00:00:00   2018.000000    NaN       NaN
# max               2021-09-25 00:00:00   2021.000000    NaN       NaN
# std                               NaN      9.674679    NaN       NaN
#
#                            listed_in  \
# count                           6173
# unique                           359
# top     Dramas, International Movies
# freq                             361
# mean                             NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
# std                              NaN
#
#                                               description     num_cast
# count                                                6173  6173.000000
# unique                                               6150          NaN
# top     Paranormal activity at a lush, abandoned prope...          NaN
# freq                                                    4          NaN
# mean                                                  NaN     7.441763
# min                                                   NaN     1.000000
# 25%                                                   NaN     5.000000
# 50%                                                   NaN     8.000000
# 75%                                                   NaN    10.000000
# max                                                   NaN    44.000000
# std                                                   NaN     4.186713

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['type_encoded'] = label_encoder.fit_transform(df['type'])

# %%
df['type_encoded']
# Out:
# 0       0
# 2       1
# 5       1
# 6       0
# 7       0
#        ..
# 8801    0
# 8802    0
# 8804    0
# 8805    0
# 8806    0
# Name: type_encoded, Length: 6173, dtype: int64
